# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread("as.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768>

# %%
b_img = cv2.resize(image, (image.shape[1] // 3, image.shape[0] // 3), interpolation=cv2.INTER_AREA)
b_img = cv2.resize(b_img, (image.shape[1], image.shape[0]), interpolation=cv2.INTER_NEAREST)

cv2_imshow(b_img)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768>
